# %% [markdown]
# # Live - Jupyter Notebook
#
# Esse arquivo é referente à live sobre o Jupyter Notebook.

# %%
print('Live - Jupyter Notebook')
# Out:
# Live - Jupyter Notebook

# %% [markdown]
# ### Calculando a média
#
# $$m = \frac{x_1 + x_2 + ... + x_n}{n}$$

# %%
import numpy as np

a = np.arange(1, 10, 1)

a.mean()
# Out:
# 5.0

# %% [markdown]
# ## Utilizando plots no Jupyter Notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 100)
y = np.sin(x)

plt.figure(figsize=(12,8))
plt.plot(x, y)

# %%
print(a)
# Out:
# [1 2 3 4 5 6 7 8 9]
